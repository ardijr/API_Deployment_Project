# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('../data/test_2025.csv')
df.head(5)
# Out:
#    claim_number  age_of_driver gender  marital_status  safty_rating  \
# 0          2309             38      M             1.0            87
# 1         22405             43      M             1.0            97
# 2         23398             49      M             1.0            75
# 3         25059             55      M             1.0            70
# 4          2665             22      M             1.0            88
#
#    annual_income  high_education_ind  address_change_ind living_status  \
# 0          56489                   1                   1           Own
# 1         112438                   0                   0           Own
# 2          62518                   1                   0           Own
# 3          96372                   1                   1          Rent
# 4          85049                   0                   1          Rent
#
#    zip_code  ... witness_present_ind liab_prct channel  \
# 0     15012  ...                 0.0        64  Broker
# ...

# %%
sample = df.sample(5, random_state=42)
sample_dict = sample.to_dict(orient='records')
sample_dict
# Out:
# [{'claim_number': 4422,
#   'age_of_driver': 37,
#   'gender': 'M',
#   'marital_status': 1.0,
#   'safty_rating': 83,
#   'annual_income': 116012,
#   'high_education_ind': 1,
#   'address_change_ind': 0,
#   'living_status': 'Own',
#   'zip_code': 80004,
#   'claim_date': '8/30/2016',
#   'claim_day_of_week': 'Tuesday',
#   'accident_site': 'Local',
#   'past_num_of_claims': 0,
#   'witness_present_ind': 0.0,
#   'liab_prct': 100,
#   'channel': 'Broker',
#   'policy_report_filed_ind': 1,
#   'claim_est_payout': 4985.68,
#   'age_of_vehicle': 4,
#   'vehicle_category': 'Large',
#   'vehicle_price': 54836.204168910524,
#   'vehicle_color': 'blue',
#   'vehicle_weight': 7849.137798999999},
#  {'claim_number': 22281,
#   'age_of_driver': 48,
#   'gender': 'M',
#   'marital_status': 1.0,
#   'safty_rating': 83,
#   'annual_income': 48740,
#   'high_education_ind': 0,
#   'address_change_ind': 1,
#   'living_status': 'Own',
#   'zip_code': 50055,
#   'claim_date': '3/9/2015',
# ...

# %%
response =requests.post('http://127.0.0.1:8000/predict', json=sample_dict)

# %%
response.json()
# Out:
# {'response': [0, 0, 0, 0, 1]}

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable
